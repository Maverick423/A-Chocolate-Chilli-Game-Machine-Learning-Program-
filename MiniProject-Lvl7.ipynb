// %% [markdown]
// # Mini Project
// # Level 7
// ## Maverick
// ## 11/11/2025
// ## Version 1

// %% [markdown]
// ## Summary of the Question
//
// As above but the program also keeps an array of records. Each array entry corresponds to a number of chocolates left so possible state of the game. Each record has three boolean fields standing for “eat one chocolate”, “eat two chocolates” or “eat three chocolates’. All are set to true initially except for at array position one in which only the value for “eat one ..” is true; and array position two in which only “eat one…” and “eat two …” are true. The program then only makes moves on its turn corresponding to the record being true for that move. Array position 0 is not used. If the program makes a move and then immediately loses then the entry for that move is set to false. The program now resigns immediately if all booleans in the record for the current position are false (as all lead to losses). It then changes the boolean flag for its last move (to false so it won’t make that move again if in the same position).

// %% [markdown]
// ## Justification that the program passes this level
// This is based on tick boxes at start of the question description for this exercise.
// - I can EXPLAIN HOW MY PROGRAM WORKS
// - I wrote this program myself
// - All the constructs, style and features above AND
// - All the constructs, style and features above AND
// - BOTH significant file input AND significant file output
// - Excellent style over comments, indentation, variable usage, final variables etc.
// - Program is fully composed into methods so excellent use of methods throughout
// - All variables are defined in methods and have minimum scope

// %% [markdown]
// ## Justification that the program passes this level
// This is based on tick boxes at start of the question description for this exercise.
// - I can EXPLAIN HOW MY PROGRAM WORKS
// - I wrote this program myself
// - All the constructs, style and features above AND
// -❑ BOTH significant file input AND significant file output-
// ❑ Excellent style over comments, indentation, variable usage, final variables etc-
// ❑ Program is fully composed into methods so excellent use of methods througho-t
// ❑ All variables are defined in methods and have minimum scopepe

// %% [markdown]
// ### Previously Done
//
// #### Summary

// %%
// Maverick Anushk Fernandes
// 24/10/2025
// VERSION 1

/* 
States the rules of the game. Than asks the user to input thier name and how many chocolates they wish to start with.
At the end of the method Introduction it returns the number of chocolate which is stored in numChocolate in main function.
Machine and user take turns to eat the chocolates until there are 0 left for a certain amount of games which the user decides.
At the end depending on who won the most it will say "Winner is machine" or "Winner is (name of user)" or "Its a draw".
Stores the record in memory, finds bad moves and avoids them.
*/

import java.util.Scanner; // Needed to make Scanner available
import java.util.Random; // Needed to make Random available
import java.util.ArrayList; // Needed to make ArrayList available
import java.util.Arrays; // Needed to make Arrays available

class ChocolateChilliGame { // START ChocolateChilliGame
    
    public static void main (String [] arg) { // START main
        Random random = new Random();
        Scanner scanner = new Scanner(System.in);
        String[] playerInfo = new String[3]; // number of chocolate to start with
        Rules(); // Method call
        playerInfo = Introduction(scanner); // Method call
        GameLoop(scanner, random, playerInfo);
        scanner.close();
        return;
    } // END main
    
    public static void Rules() { // START Rules
        System.out.println("Chocolate Chilli Game Rules\n"); // Rules
        System.out.println("1. There is a pile of chocolates on the table.");
        System.out.println("2. Two players take turns");
        System.out.println("3. On your turn, you must eat 1, 2, or 3 chocolates from the pile.");
        System.out.println("4. Players must take at least one chocolate each turn.");
        System.out.println("5. The player who has to take the last chocolate is the loser - they have to eat the chilli instead of chocolate!");
        System.out.println("6. The game ends as soon as there are no chocolates left.");
        System.out.println("7. The aim is to avoid taking the last chocolate - so you must try to force your opponent to take it.\n");
        return;
    } // END Rules

    public static String[] Introduction(Scanner scanner) { // START Introduction
        String[] intro = new String[3]; // [name, intial chocolate, total games]
        System.out.println("What's your name?");
        intro[0] = scanner.nextLine(); // name
        do { // validation
        System.out.println("How many chocolates would you like to start with? (Greater than 10 inclusive)");
        intro[1] = scanner.nextLine(); // intial chocolate
        }while (Integer.parseInt(intro[1])<10);
        do { // validation
        System.out.println("How many games do you want to play?");
        intro[2] = scanner.nextLine(); // total games
        }while(Integer.parseInt(intro[2])<=0);
        System.out.println("Thanks, " + intro[0] + "! There are " + intro[1] + " chocolates on the table. I will go first.\n");
        return intro;
    } // END Introduction
    
    public static void GameLoop(Scanner scanner, Random random, String[] playerInfo) { // START GameLoop
        int leftChocolates = Integer.parseInt(playerInfo[1]); // initial chocolate
        int totalGame = Integer.parseInt(playerInfo[2]); // number of games to play
        boolean machineWon;
        String winner = null;
        int[] allGame = new int[totalGame];
        ArrayList<Integer> listNum = new ArrayList<>();
        ArrayList<ArrayList<Boolean>> memory = Memory();
        for (int i = 1; i<=totalGame; i++){
                System.out.println("Game " + i);
                do{ // so all variables are initialised 
                    leftChocolates = Machine(memory, random, leftChocolates); // machines turn
                    machineWon = true;
                    listNum.add(leftChocolates);
                    if (leftChocolates<=0) { // checks if there are any chocolates left 
                        break; // breaks do while loop
                    }
                    leftChocolates = Player(scanner, leftChocolates); // players turn
                    machineWon = false;
                    listNum.add(leftChocolates);
                } while (!(leftChocolates<=0)); // runs until there is no more chocolates left
            leftChocolates = Integer.parseInt(playerInfo[1]); // gets original starting number of chocolates as new round
            allGame = Score(playerInfo,machineWon,allGame); //records who won
            winner = Result(playerInfo,allGame);
            }
        if (winner.equals("Draw")){ // draw
            System.out.println("Its a draw");
        }else{
            System.out.println("Winner is " + winner); // someone won
        }
        return;
    } // END GameLoop

    public static int Player(Scanner scanner, int chocolatesLeft) { // START Player
        int pickedChocolates;
        do { // do while loop so it runs once before checking condition
            System.out.println("How many chocolates do you wish to eat? (1, 2 or 3)");
            pickedChocolates = Integer.parseInt(scanner.nextLine()); // converts string to int
        } while (!(pickedChocolates == 1 || pickedChocolates == 2 || pickedChocolates == 3)); // makes sure user pick 1, 2 or 3
        if (pickedChocolates > chocolatesLeft) {
            System.out.println("There are only " + chocolatesLeft + " left. Try again\n");
            chocolatesLeft = Player(scanner, chocolatesLeft);
        }else {
            chocolatesLeft -= pickedChocolates; // subtracts by input
        }
        System.out.println("There are " + chocolatesLeft + " left.\n"); // total number of chocolates left
        return chocolatesLeft;
    } //END Player
    
    public static int Machine(ArrayList<ArrayList<Boolean>> memory, Random random, int chocolatesLeft) { //START Machine
        int pickedChocolates = MemoryGetNum(random, memory, chocolatesLeft);
        ArrayList<Integer> moveSet = new ArrayList<Integer>();
        ArrayList<Integer> listNum = CheckMemory(memory, chocolatesLeft); // list of all moves
        if (listNum.isEmpty()) { 
            return 0; // all move set is false so can't pick 
        } 
        System.out.println("The machine has picked " + pickedChocolates);
        if (pickedChocolates > chocolatesLeft) {
            MemoryRemove(memory, null, chocolatesLeft, pickedChocolates); // if what machine picked exceeds number of chocolate left than removes it from move set
            chocolatesLeft = Machine(memory, random, chocolatesLeft); // calls it again to get different value
        }else {
            chocolatesLeft -= pickedChocolates; // subtracts by input
        }
        System.out.println("There are " + chocolatesLeft + " left.\n"); // total number of chocolates left       
        return chocolatesLeft;
    } // END Machine
    
    public static int[] Score(String[] infoPlayer, boolean machineWin, int[] gameTotal) { // START Score
        int j = gameTotal.length; // j is max
        for(int i = 0; i<gameTotal.length; i++) {
            if (gameTotal[i] == 0) { // when initialised contains all 0 
                j-=1; // gets the position of the next empty space
            }
        }
        if (machineWin) { // checks boolean value
            gameTotal[j] = 1; // machine won
        }else {
            gameTotal[j] = 2; // player won
        }
        return gameTotal;
    } // END Score
    
    public static String Result(String[] infoPlayer, int[] gameResult) { // START Result
        String name = infoPlayer[0]; //S first value has name
        int playerScore = 0; // start score
        int machineScore = 0; // start score
        for (int i = 0; i<gameResult.length; i++) {
            if (gameResult[i] == 2) { // player won 
                playerScore += 1;
            }else if (gameResult[i] == 1) { // machine won
                machineScore += 1;
            }
        }
        System.out.println(name + ": " + playerScore); // print score 
        System.out.println("Machine: " + machineScore + "\n"); // print score
        if (playerScore>machineScore) { // player won
            return infoPlayer[0];
        }else if (playerScore<machineScore) { // machine won
            return "Machine";
        }else {
            return "Draw"; // draw
        }
    } // END Result

    public static ArrayList<ArrayList<Boolean>> Memory() { // START Memory
        ArrayList<ArrayList<Boolean>> memory = new ArrayList<>(); // 2d array with dynamic memory 
        for (int i = 0; i < 100; i++){
            memory.add(new ArrayList<>(Arrays.asList(true,true,true))); // initialising the dynamic array with 3 numbers
        }
        return memory;
    } // END Memory

    public static void MemoryRemove(ArrayList<ArrayList<Boolean>> memory, ArrayList<Integer> moves,  int chocolatesLeft, int chocolatePicked) { // START MemoryRemove
        memory.get(chocolatesLeft-1).set(chocolatePicked-1,false); // since 2d gets inner list [[],[],[]] from it makes whatever was picked false 
        if (CheckMemory(memory,chocolatesLeft).isEmpty()){ // checks if all of it is false
            EditMemory(memory,moves); // changes the previous move 
        }
        return;
    } // END MemoryRemove
    
    public static int MemoryGetNum(Random random, ArrayList<ArrayList<Boolean>> memory, int chocolatesLeft) { // START MemoryGetNum
        ArrayList<Integer> listNum = new ArrayList<>(); // dynamic 1d array
        listNum = CheckMemory(memory, chocolatesLeft); // gets all possible move so (1,2,3) based on which is true 
        int pickedChocolates = listNum.get(random.nextInt(listNum.size())); // randomly picks one of the availabe options
        return pickedChocolates;
    } // END MemoryGetNum

    public static ArrayList<Integer> CheckMemory(ArrayList<ArrayList<Boolean>> memory, int chocolatesLeft){
        ArrayList<Integer> listNum = new ArrayList<>(); // dynamic 1d array
        for (int i = 0; i<memory.get(chocolatesLeft-1).size(); i++){ // [[],[]] gets the size of the inner array 
            if (memory.get(chocolatesLeft-1).get(i)){ // checks if true eg [[true,false,true],[]]
                listNum.add(i+1); // if true it will return the index value so new list will be [1,3] from above
            }
        }
        return listNum;
    }

    public static void EditMemory(ArrayList<ArrayList<Boolean>> memory, ArrayList<Integer> moves) { // END EditMemory
        if (moves == null || moves.size() < 4) // validation 
            return;
        for (int i = moves.size()-2; i >= 0; i-=2){ // finds the position of the empty (all false) inner array
            if (CheckMemory(memory, moves.get(i)).isEmpty()){ // checks if there are possible moves list is empty
                int pickedChocolate = moves.get(i)-moves.get(i-2); // works out what machine picked 
                memory.get(moves.get(i)-1).set(pickedChocolate-1,false); // [12,8,5,4] is all is false for 4 in the inner than will go to 8 and change that  
            }
        }
        return;
    } // END EditMemory 

   
} // END ChocolateChilliGame

// %% [markdown]
// ### readMemory
//
// #### What it does
// Reads the array from the memory, than returns the memory so it can be used in the current game.
//
// #### Implementation (how it works)
// The first if statement checks if the "Memory.txt" file exits and it has read write access to it, if it doesn't than it creates a new file called that and adds a space to it so its not empty and causes error in code. Since there is nothing in the memory it will return a a 2d array with 1 size so [[true,true,true]]. The next part checks if the file is empty if it is than does the same thing. If it already contains data which will be [true true true] [] [] and so on it will combine it all into single array so [true,true,true,true,true,true] than added to to the memory which is 2d array also nested for loop because i want to added it to inner loop so after 3 added to the inner array it moves to next in outer array.

// %%
public static boolean[][] readMemory() throws IOException {
        File file = new File("Memory.txt");
        int k=0;
        if (!(file.exists())) {
            PrintWriter pw = new PrintWriter(new FileWriter(file));
            pw.println(""); // writes in the file so not empty
            pw.close();
            return new boolean[0][3]; 
        }
        BufferedReader readFile = new BufferedReader(new FileReader("Memory.txt"));
        String text= readFile.readLine();
        if (text == null || text.isEmpty()) { // checks if file is empty 
            readFile.close();
            return new boolean[0][3]; // retuns a 2d array with inner size 3
        }
        text= text.replace("[", ""); 
        text= text.replace("] ", ""); // makes the array go from [...] [...] [...] to [......] 
        String[] mem = text.split(" "); // makes it into a functioning array with commas [., ., ., .]
        boolean[][] memory = new boolean[mem.length/3][3];
        for (int i = 0; i<mem.length/3; i++){
            for (int j = 0; j<3; j++){
                memory[i][j] = Boolean.parseBoolean(mem[k]);
                k++;
            }
        }
        readFile.close();
        return memory;

// %% [markdown]
// ### writeMemory
//
//
// #### What it does
// Adds all the data to a string so it can be the way i want it so [...] [...] [...] than write the string in the file to store it there also the dots are either true or false.
//
// #### Implementation (how it works)
// First it checks if the number of chocolates at start is bigger than or equal to number of chocolates stored in memory. I did this because if they are i can just write the memory from this game into the file. This is done by adding all the data from memory to string which is than written in file. If its not than i will write the memory into string than add the extra to string and write that into file. For example picked chocolate is 11 and the chocolate picked in file is 15, it will first add 1-11 to string from memory than add 12-15 from file which was read to it.

// %%
    public static void writeMemory(boolean[][] memory, boolean[][] readMemory) throws IOException{
        String data="";
        PrintWriter writeFile = new PrintWriter(new FileWriter("Memory.txt"));
        if (memory.length >= readMemory.length){ // this game played picked more or equal chocolate than past games
            for (int i = 0; i<memory.length;i++){
                data = data +"[";
                for (int j = 0; j<3;j++){
                    data = data + memory[i][j];
                    data = data +" ";
                }
                data = data + "] "; // writing in the file in this formet [...] [...]
            }
            
        }else{ // this game played picked less chocolate than past games
            for (int i = 0; i < memory.length; i++){ 
                for (int j = 0; j < 3; j++){
                    readMemory[i][j] = memory[i][j];
                }
            }
            data = data + "[";
            for (int i = 0; i<readMemory.length;i++){
                for (int j = 0; j<3;j++){
                    data = data + readMemory[i][j];
                    data = data +" ";
                }
                data = data + "] "; // writing in the file in this formet [...] [...]
            }
        }
        writeFile.println(data); // writing the string with data into memory
        writeFile.close();
    }

// %% [markdown]
// ## The complete program
// This version will only compile here. To run it copy it into a file called initials.java on your local computer and compile and run it there.

// %%
// Maverick Anushk Fernandes
// 24/10/2025
// VERSION 1

/* 
States the rules of the game. Than asks the user to input thier name and how many chocolates they wish to start with.
At the end of the method Introduction it returns the number of chocolate which is stored in numChocolate in main function.
Machine and user take turns to eat the chocolates until there are 0 left for a certain amount of games which the user decides.
At the end depending on who won the most it will say "Winner is machine" or "Winner is (name of user)" or "Its a draw".
Stores the record in memory, finds bad moves and avoids them. 
The memory is written in a file text so it remembers its past game and doesnt repeat bad moves.
*/




// add comment for all methods 






import java.util.Scanner; // Needed to make Scanner available
import java.util.Random; // Needed to make Random available
import java.util.Arrays;
import java.io.*; // Needed to make io available

class Finalmemory{
    public static boolean[][] memory;
} 

class ChocolateChilliGame { // START ChocolateChilliGame


    
    public static void main (String [] arg) throws IOException { // START main
        Random random = new Random();
        Scanner scanner = new Scanner(System.in);
        String[] playerInfo = new String[3]; // number of chocolate to start with
        Rules(); // Method call
        playerInfo = Introduction(scanner); // Method call
        GameLoop(scanner, random, playerInfo);
        scanner.close();
        return;
    } // END main
    
    public static void Rules() { // START Rules
        System.out.println("Chocolate Chilli Game Rules\n"); // Rules
        System.out.println("1. There is a pile of chocolates on the table.");
        System.out.println("2. Two players take turns");
        System.out.println("3. On your turn, you must eat 1, 2, or 3 chocolates from the pile.");
        System.out.println("4. Players must take at least one chocolate each turn.");
        System.out.println("5. The player who has to take the last chocolate is the loser - they have to eat the chilli instead of chocolate!");
        System.out.println("6. The game ends as soon as there are no chocolates left.");
        System.out.println("7. The aim is to avoid taking the last chocolate - so you must try to force your opponent to take it.\n");
        return;
    } // END Rules

    public static String[] Introduction(Scanner scanner) { // START Introduction
        String[] intro = new String[3]; // [name, intial chocolate, total games]
        System.out.println("What's your name?");
        intro[0] = scanner.nextLine(); // name
        do { // validation
        System.out.println("How many chocolates would you like to start with? (Greater than 10 inclusive)");
        intro[1] = scanner.nextLine(); // intial chocolate
        }while (Integer.parseInt(intro[1])<10);
        do { // validation
        System.out.println("How many games do you want to play?");
        intro[2] = scanner.nextLine(); // total games
        }while(Integer.parseInt(intro[2])<=0);
        System.out.println("Thanks, " + intro[0] + "! There are " + intro[1] + " chocolates on the table. I will go first.\n");
        return intro;
    } // END Introduction
    
    public static void GameLoop(Scanner scanner, Random random, String[] playerInfo) throws IOException{ // START GameLoop
        int leftChocolates = Integer.parseInt(playerInfo[1]); // initial chocolate
        int totalGame = Integer.parseInt(playerInfo[2]); // number of games to play
        boolean machineWon;
        String winner = null;
        int[] allGame = new int[totalGame];
        int[] allMoves = new int[leftChocolates];
        boolean[][] readFile = readMemory();
        boolean[][] memory = Memory(leftChocolates,readFile);
        for (int i = 1; i<=totalGame; i++){
            int count =0;
            System.out.println("Game " + i);
            do{ // so all variables are initialised 
                leftChocolates = Machine(memory, allMoves, random, leftChocolates, count); // machines turn
                if (leftChocolates==-1){
                    machineWon=false;
                    break;
                }
                machineWon = true; 
                allMoves[count] = leftChocolates;
                count+=1;
                if (leftChocolates<=0) { // checks if there are any chocolates left 
                    break; // breaks do while loop
                }
                leftChocolates = Player(scanner, leftChocolates); // players turn
                machineWon = false;
                allMoves[count] = leftChocolates;
                count+=1;
            } while (!(leftChocolates<=0)); // runs until there is no more chocolates left
            leftChocolates = Integer.parseInt(playerInfo[1]); // gets original starting number of chocolates as new round
            allGame = Score(playerInfo,machineWon,allGame); //records who won
            winner = Result(playerInfo,allGame);
            if (allGame[i-1]==2){
                MemoryRemove(memory, allMoves, -1, count-1); 
            }                                           
        } 
        if (winner.equals("Draw")){ // draw
            System.out.println("Its a draw");
        }else{
            System.out.println("Winner is " + winner); // someone won
        }
        writeMemory(memory, readFile);
        return;
    } // END GameLoop

    public static int Player(Scanner scanner, int chocolatesLeft) { // START Player
        int pickedChocolates;
        do { // do while loop so it runs once before checking condition
            System.out.println("How many chocolates do you wish to eat? (1, 2 or 3)");
            pickedChocolates = Integer.parseInt(scanner.nextLine()); // converts string to int
        } while (!(pickedChocolates == 1 || pickedChocolates == 2 || pickedChocolates == 3)); // makes sure user pick 1, 2 or 3
        if (pickedChocolates > chocolatesLeft) {
            System.out.println("There are only " + chocolatesLeft + " left. Try again\n");
            chocolatesLeft = Player(scanner, chocolatesLeft);
        }else {
            chocolatesLeft -= pickedChocolates; // subtracts by input
        }
        System.out.println("There are " + chocolatesLeft + " left.\n"); // total number of chocolates left
        return chocolatesLeft;
    } //END Player
    
    public static int Machine(boolean[][] memory, int[] moves, Random random, int chocolatesLeft, int index) { //START Machine
        int pickedChocolates = MemoryGetNum(random, memory, chocolatesLeft);
        int [] listNum = CheckMemory(memory, chocolatesLeft); // list of all moves that can be picked
        if (listNum[0]==0 && listNum[1]==0 && listNum[2]==0 || pickedChocolates == 0) { 
            return -1; // all move set is false so can't pick 
        }
        System.out.println("The machine has picked " + pickedChocolates);
        if (pickedChocolates > chocolatesLeft) {
            System.out.println("macine picked : " + pickedChocolates);
            MemoryRemove(memory, moves, pickedChocolates, index); // if what machine picked exceeds number of chocolate left than removes it from move set
            chocolatesLeft = Machine(memory, moves, random, chocolatesLeft, index); // calls it again to get different value
        }else {
            chocolatesLeft -= pickedChocolates; // subtracts by input
        }
        System.out.println("There are " + chocolatesLeft + " left.\n"); // total number of chocolates left       
        return chocolatesLeft;
    } // END Machine
    
    public static int[] Score(String[] infoPlayer, boolean machineWin, int[] gameTotal) { // START Score
        int j = gameTotal.length; // j is max
        for(int i = 0; i<gameTotal.length; i++) {
            if (gameTotal[i] == 0) { // when initialised contains all 0 
                j-=1; // gets the position of the next empty space
            }
        }
        if (machineWin) { // checks boolean value
            gameTotal[j] = 1; // machine won
        }else {
            gameTotal[j] = 2; // player won
        }
        return gameTotal;
    } // END Score
    
    public static String Result(String[] infoPlayer, int[] gameResult) { // START Result
        String name = infoPlayer[0]; //S first value has name
        int playerScore = 0; // start score
        int machineScore = 0; // start score
        for (int i = 0; i<gameResult.length; i++) {
            if (gameResult[i] == 2) { // player won 
                playerScore += 1;
            }else if (gameResult[i] == 1) { // machine won
                machineScore += 1;
            }
        }
        System.out.println(name + ": " + playerScore); // print score 
        System.out.println("Machine: " + machineScore + "\n"); // print score
        if (playerScore>machineScore) { // player won
            return infoPlayer[0];
        }else if (playerScore<machineScore) { // machine won
            return "Machine";
        }else {
            return "Draw"; // draw
        }
    } // END Result

    public static boolean[][] Memory(int totalChocolate, boolean[][] readMemory) { // START Memory
        boolean[][] memory = new boolean[totalChocolate][3]; // 2d array with dynamic memory 
        if (totalChocolate<=readMemory.length){
            for (int i = 0; i < totalChocolate; i++){
                for (int j = 0; j < 3; j++){
                    memory[i][j] = readMemory[i][j];
                }
            }
            System.out.println(Arrays.deepToString(memory));
        } else {
            for (int i = 0; i < readMemory.length; i++){
                for (int j = 0; j < 3; j++){
                    memory[i][j] = readMemory[i][j];
                }
            }
            for (int i = readMemory.length; i < totalChocolate; i++){
                for (int j = 0; j < 3; j++){
                    memory[i][j] = true;
                }
            }
            System.out.println(Arrays.deepToString(memory));
        }
        return memory;
    } // END Memory

    public static void MemoryRemove(boolean[][] memory, int[] moves, int chocolatePicked, int index) { // START MemoryRemove
        if (!(chocolatePicked ==-1)){
            memory[moves[index-2]-1][chocolatePicked-1] = false; //[13,11,8,7,4,3,0,0,0]
            if (CheckMemory(memory,chocolatePicked)[0]==0 && CheckMemory(memory,chocolatePicked)[1]==0 && CheckMemory(memory,chocolatePicked)[2]==0){ // checks if all of it is false
                EditMemory(memory,moves,index); // changes the previous move 
            }
        }else{           //[15,12,8,6,3,0]                                                   
            memory[moves[index-2]-1][(moves[index-2]-moves[index-1])-1] = false;
            if (CheckMemory(memory,moves[index-2]-moves[index-1])[0]==0 && CheckMemory(memory,moves[index-2]-moves[index-1])[1]==0 && CheckMemory(memory,moves[index-2]-moves[index-1])[2]==0){ // checks if all of it is false
                EditMemory(memory,moves,index); // changes the previous move 
            }
        }
        return;
    } // END MemoryRemove
    
    public static int MemoryGetNum(Random random, boolean[][] memory, int chocolatesLeft) { // START MemoryGetNum
        int[] listNum = CheckMemory(memory, chocolatesLeft); // gets all possible move so (1,2,3) based on which is true 
        int values=0;
        int number=0;
        for (int i=0; i<3; i++){
            if (listNum[i]!=0){
                values+=1;
                number = listNum[i];
            }
        }
        if (values > 1){
            int pickedChocolates = listNum[random.nextInt(values-1)]; // randomly picks one of the availabe options
            return pickedChocolates;
        }else if (values == 1){
           return number;
        }else{
            return 0;
        }
    } // END MemoryGetNum

    public static int[] CheckMemory(boolean[][] memory, int chocolatesLeft){
        int[] listNum = new int[3]; // static 1d array
        int index=0;
        for (int i = 0; i<3; i++){ // [[],[]] gets the size of the inner array 
            if (memory[chocolatesLeft-1][i]){ // checks if true eg [[true,false,true],[]]
                listNum[index]=i+1; // if true it will return the index value so new list will be [1,3,0] from above
                index+=1;
            }
        }
        return listNum;
    }

    public static void EditMemory(boolean[][] memory, int[] moves, int index) { // END EditMemory
        //[15,12,8,6,3,0]
        
        for (int i = index; i >= 0; i-=2){ // finds the position of the empty (all false) inner array
            if (!(CheckMemory(memory, moves[i])[0]==0 && CheckMemory(memory, moves[i])[1]==0 && CheckMemory(memory, moves[i])[2]==0)){ // checks if there are possible moves list is empty
                memory[moves[i]-1][moves[i]-moves[i+1]-1] = false; // [12,8,5,4] is all is false for 4 in the inner than will go to 8 and change that  
                break;
            }
        }
        return;
    } // END EditMemory 
    
    public static void writeMemory(boolean[][] memory, boolean[][] readMemory) throws IOException{
        String data="";
        PrintWriter writeFile = new PrintWriter(new FileWriter("Memory.txt"));
        if (memory.length >= readMemory.length){ // this game played picked more or equal chocolate than past games
            for (int i = 0; i<memory.length;i++){
                data = data +"[";
                for (int j = 0; j<3;j++){
                    data = data + memory[i][j];
                    data = data +" ";
                }
                data = data + "] "; // writing in the file in this formet [...] [...]
            }
            
        }else{ // this game played picked less chocolate than past games
            for (int i = 0; i < memory.length; i++){ 
                for (int j = 0; j < 3; j++){
                    readMemory[i][j] = memory[i][j];
                }
            }
            data = data + "[";
            for (int i = 0; i<readMemory.length;i++){
                for (int j = 0; j<3;j++){
                    data = data + readMemory[i][j];
                    data = data +" ";
                }
                data = data + "] "; // writing in the file in this formet [...] [...]
            }
        }
        writeFile.println(data); // writing the string with data into memory
        writeFile.close();
    }
    
    public static boolean[][] readMemory() throws IOException {
        File file = new File("Memory.txt");
        int k=0;
        if (!(file.exists())) {
            PrintWriter pw = new PrintWriter(new FileWriter(file));
            pw.println(""); // writes in the file so not empty
            pw.close();
            return new boolean[0][3]; 
        }
        BufferedReader readFile = new BufferedReader(new FileReader("Memory.txt"));
        String text= readFile.readLine();
        if (text == null || text.isEmpty()) { // checks if file is empty 
            readFile.close();
            return new boolean[0][3]; // retuns a 2d array with inner size 3
        }
        text= text.replace("[", ""); 
        text= text.replace("] ", ""); // makes the array go from [...] [...] [...] to [......] 
        String[] mem = text.split(" "); // makes it into a functioning array with commas [., ., ., .]
        boolean[][] memory = new boolean[mem.length/3][3];
        for (int i = 0; i<mem.length/3; i++){
            for (int j = 0; j<3; j++){
                memory[i][j] = Boolean.parseBoolean(mem[k]);
                k++;
            }
        }
        readFile.close();
        return memory;
    }
    
    public static boolean[][] Fmemory(){
        boolean[][] Allmemory = Finalmemory.memory; 
        return Allmemory;
    }   
} // END ChocolateChilliGame

// %% [markdown]
// ## Testing the complete program
// Run the following test calls for each test in the test plan to run the complete program.

// %% [markdown]
// ### Test Plan: Test 1
// Whoever has to pick when there is 4 chocolates left loses so i will get the machine to pick when there are 4 chocolates left'
//
// The program should output different number for each of the 3 picks so if it picks 1 first it needs to pick the other 2.

// %%
ChocolateChilliGame.main(null);
// Out:
// Chocolate Chilli Game Rules
//
// 1. There is a pile of chocolates on the table.
// 2. Two players take turns
// 3. On your turn, you must eat 1, 2, or 3 chocolates from the pile.
// 4. Players must take at least one chocolate each turn.
// 5. The player who has to take the last chocolate is the loser - they have to eat the chilli instead of chocolate!
// 6. The game ends as soon as there are no chocolates left.
// 7. The aim is to avoid taking the last chocolate - so you must try to force your opponent to take it.
//
// What's your name?
//  Mav
// How many chocolates would you like to start with? (Greater than 10 inclusive)
//  13
// How many games do you want to play?
//  3
// Thanks, Mav! There are 13 chocolates on the table. I will go first.
//
// Game 1
// The machine has picked 2
// There are 11 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  3
// There are 8 left.
//
// The machine has picked 1
// There are 7 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  3
// There are 4 left.
//
// The machine has picked 1
// There are 3 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  3
// There are 0 left.
//
// Mav: 1
// Machine: 0
//
// Game 2
// The machine has picked 1
// There are 12 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  2
// There are 10 left.
//
// The machine has picked 2
// There are 8 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  1
// There are 7 left.
//
// The machine has picked 2
// There are 5 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  1
// There are 4 left.
//
// The machine has picked 2
// There are 2 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  2
// There are 0 left.
//
// Mav: 2
// Machine: 0
//
// Game 3
// The machine has picked 3
// There are 10 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  3
// There are 7 left.
//
// The machine has picked 2
// There are 5 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  1
// There are 4 left.
//
// The machine has picked 3
// There are 1 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
//  1
// There are 0 left.
//
// Mav: 3
// Machine: 0
//
// Winner is Mav

// %% [markdown]
// ### Test 1 from Computer
// Chocolate Chilli Game Rules
//
// 1. There is a pile of chocolates on the table.
// 2. Two players take turns
// 3. On your turn, you must eat 1, 2, or 3 chocolates from the pile.
// 4. Players must take at least one chocolate each turn.
// 5. The player who has to take the last chocolate is the loser - they have to eat the chilli instead of chocolate!
// 6. The game ends as soon as there are no chocolates left.
// 7. The aim is to avoid taking the last chocolate - so you must try to force your opponent to take it.
//
// What's your name?
// Mav
// How many chocolates would you like to start with? (Greater than 10 inclusive)
// 13
// How many games do you want to play?
// 3
// Thanks, Mav! There are 13 chocolates on the table. I will go first.
//
// [[true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [true, true, true], [t
// rue, true, true]]
// Game 1
// The machine has picked 2
// There are 11 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 13
// How many chocolates do you wish to eat? (1, 2 or 3)
// 3
// There are 8 left.
//
// The machine has picked 1
// There are 7 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 3
// There are 4 left.
//
// The machine has picked 2
// There are 2 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 2
// There are 0 left.
//
// Mav: 1
// Machine: 0
//
// Game 2
// The machine has picked 1
// There are 12 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 3
// There are 9 left.
//
// The machine has picked 2
// There are 7 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 3
// There are 4 left.
//
// The machine has picked 1
// There are 3 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 3
// There are 0 left.
//
// Mav: 2
// Machine: 0
//
// Game 3
// The machine has picked 2
// There are 11 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 3
// There are 8 left.
//
// The machine has picked 2
// There are 6 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 2
// There are 4 left.
//
// The machine has picked 3
// There are 1 left.
//
// How many chocolates do you wish to eat? (1, 2 or 3)
// 1
// There are 0 left.
//
// Mav: 3
// Machine: 0
//
// Winner is Mav

// %% [markdown]
// ### Test 1 Result from Computer
// [true true true ] [true true true ] [true true true ] [false false false ] [true true true ] [true true true ] [true true true ] [true true true ] [true true true ] [true true true ] [true true true ] [true true true ] [true true true ]

// %% [markdown]
// **END OF LITERATE DOCUMENT**
